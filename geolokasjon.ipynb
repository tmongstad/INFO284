# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
import geodatasets

# %%
import sys in sys.modules

'geopandas'
# Out:
# True

# %%
chicago = geopandas.read_file(geodatasets.get_path("geoda.chicago_commpop"))
groceries = geopandas.read_file(geodatasets.get_path("geoda.groceries"))
# Out:
# Downloading file 'grocery.zip' from 'https://geodacenter.github.io/data-and-lab//data/grocery.zip' to '/Users/torsteinmongstad/Library/Caches/geodatasets'.
# Extracting 'grocery/chicago_sup.shp' from '/Users/torsteinmongstad/Library/Caches/geodatasets/grocery.zip' to '/Users/torsteinmongstad/Library/Caches/geodatasets/grocery.zip.unzip'
# Extracting 'grocery/chicago_sup.dbf' from '/Users/torsteinmongstad/Library/Caches/geodatasets/grocery.zip' to '/Users/torsteinmongstad/Library/Caches/geodatasets/grocery.zip.unzip'
# Extracting 'grocery/chicago_sup.shx' from '/Users/torsteinmongstad/Library/Caches/geodatasets/grocery.zip' to '/Users/torsteinmongstad/Library/Caches/geodatasets/grocery.zip.unzip'
# Extracting 'grocery/chicago_sup.prj' from '/Users/torsteinmongstad/Library/Caches/geodatasets/grocery.zip' to '/Users/torsteinmongstad/Library/Caches/geodatasets/grocery.zip.unzip'

# %%
# Examine the chicago GeoDataFrame
chicago.head()
# Out:
#          community  NID  POP2010  POP2000  POPCH   POPPERCH  popplus  popneg  \
# 0          DOUGLAS   35    18238    26470  -8232 -31.099358        0       1
# 1          OAKLAND   36     5918     6110   -192  -3.142390        0       1
# 2      FULLER PARK   37     2876     3420   -544 -15.906433        0       1
# 3  GRAND BOULEVARD   38    21929    28006  -6077 -21.698922        0       1
# 4          KENWOOD   39    17841    18363   -522  -2.842673        0       1
#
#                                             geometry
# 0  MULTIPOLYGON (((-87.60914 41.84469, -87.60915 ...
# 1  MULTIPOLYGON (((-87.59215 41.81693, -87.59231 ...
# 2  MULTIPOLYGON (((-87.62880 41.80189, -87.62879 ...
# 3  MULTIPOLYGON (((-87.60671 41.81681, -87.60670 ...
# 4  MULTIPOLYGON (((-87.59215 41.81693, -87.59215 ...

# %%
chicago.plot()
# Out:
# <Axes: >

# %%
chicago.plot(column="POP2010")
# Out:
# <Axes: >
